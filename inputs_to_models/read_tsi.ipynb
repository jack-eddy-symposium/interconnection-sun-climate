# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr

# %%
ds = xr.open_mfdataset('tsi/ncei/monthly/tsi_v02r01_monthly_*_c20170717.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1620, bounds: 2)
# Coordinates:
#   * time       (time) datetime64[ns] 1882-01-15 1882-02-15 ... 2016-12-15
# Dimensions without coordinates: bounds
# Data variables:
#     TSI        (time) float32 dask.array<chunksize=(12,), meta=np.ndarray>
#     TSI_UNC    (time) float32 dask.array<chunksize=(12,), meta=np.ndarray>
#     time_bnds  (time, bounds) datetime64[ns] dask.array<chunksize=(12, 2), meta=np.ndarray>
# Attributes: (12/28)
#     Conventions:               CF-1.6, ACDD-1.3
#     title:                     Monthly TSI calculated using NRL2 solar irradi...
#     source:                    NRLTSI2_v02r01
#     institution:               Naval Research Laboratory Space Science Divisi...
#     standard_name_vocabulary:  CF Standard Name Table v29
#     id:                        tsi_v02r01_monthly_s188201_e188212_c20170717.nc
#     ...                        ...
#     geospatial_lon_max:         180.0
#     spatial_resolution:        N/A
# ...

# %%
ds['TSI'].plot(figsize=(14,8))

# %%
tsi = ds['TSI'].to_dataframe()

# %%
tsi.to_csv('tsi/ncei/monthly/tsi_v02r01_monthly_c20170717.csv')
