# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

url = "https://raw.githubusercontent.com/jack-eddy-symposium/interconnection-sun-climate/main/data/Terminator_Unit_Cycle_1758-2030.dat"
clock = pd.read_csv(url, header=22, sep='\s+', names=['DATE', 'DECIMAL_YEAR', 'TERMINATOR_PHASE', 'CYCLE_PHASE'])
print(clock.columns)
clock
# Out:
# Index(['DATE', 'DECIMAL_YEAR', 'TERMINATOR_PHASE', 'CYCLE_PHASE'], dtype='object')
#              DATE  DECIMAL_YEAR  TERMINATOR_PHASE  CYCLE_PHASE
# 0     1758-FEB-15      1758.120             0.024        1.024
# 1     1758-MAR-15      1758.205             0.032        1.032
# 2     1758-APR-15      1758.287             0.040        1.040
# 3     1758-MAY-15      1758.372             0.049        1.049
# 4     1758-JUN-15      1758.454             0.057        1.057
# 5     1758-JUL-15      1758.539             0.065        1.065
# 6     1758-AUG-15      1758.624             0.074        1.074
# 7     1758-SEP-15      1758.706             0.082        1.082
# 8     1758-OCT-15      1758.791             0.091        1.091
# 9     1758-NOV-15      1758.873             0.099        1.099
# 10    1758-DEC-15      1758.958             0.107        1.107
# 11    1759-JAN-15      1759.044             0.116        1.116
# 12    1759-FEB-15      1759.120             0.124        1.124
# ...
